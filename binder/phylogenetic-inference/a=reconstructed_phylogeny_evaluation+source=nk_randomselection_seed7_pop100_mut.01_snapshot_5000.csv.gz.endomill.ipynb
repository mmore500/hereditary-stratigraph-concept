# %%
# Parameters
reconstructed_phylogeny_url = "https://github.com/mmore500/hereditary-stratigraph-concept/blob/7f28f68696c67737f6f18054c121769ff616758e/binder/phylogenetic-inference/a=reconstructed_phylogenies+source=nk_randomselection_seed7_pop100_mut.01_snapshot_5000.csv.gz"
original_phylogeny_url = "https://osf.io/ydxt7/"

# %%
import endomill
from nbmetalog import nbmetalog as nbm

# %%
nbm.print_metadata()
# Out:
# context: ci
# hostname: 943f9139d4bc
# interpreter: 3.8.12 (default, Jan 15 2022, 18:39:47)  [GCC 7.5.0]
# nbcellexec: 3
# nbname: reconstructed_phylogeny_evaluation_mill
# nbpath: /opt/hereditary-stratigraph-concept/binder/phylogenetic-inference/reconstructed_phylogeny_evaluation_mill.ipynb
# revision: null
# session: 0963e396-1d15-4b79-b9da-91ca0000fbab
# timestamp: 2022-03-09T04:15:29Z00:00
#
#
# IPython==7.16.1
# keyname==0.4.1
# yaml==5.3.1
# endomill==0.1.3
# nbmetalog==0.2.6
# re==2.2.1
# ipython_genutils==0.2.0
# logging==0.5.1.2
# zmq==22.3.0
# json==2.0.9
# ipykernel==5.5.3

# %%
prefix = (
    'https://github.com/mmore500/hereditary-stratigraph-concept/'
    'blob/7f28f68696c67737f6f18054c121769ff616758e/'
    'binder/phylogenetic-inference/'
)
reconstructed_phylogeny_urls = [
    prefix + 'a=reconstructed_phylogenies+source=nk_lexicaseselection_seed110_pop165_mut.01_snapshot_500.csv.gz',
    prefix + 'a=reconstructed_phylogenies+source=nk_randomselection_seed7_pop100_mut.01_snapshot_5000.csv.gz',
    prefix + 'a=reconstructed_phylogenies+source=nk_sharingselection_seed10_pop100_mut.01_snapshot_5000.csv.gz',
    prefix + 'a=reconstructed_phylogenies+source=nk_tournamentselection_seed140_pop100_mut.01_snapshot_5000.csv.gz',
]

original_phylogeny_urls = [
            # nk_ecoeaselection_seed110_pop100_mut.01_snapshot_3000.csv
#             'https://osf.io/5d3be/',
            # nk_lexicaseselection_seed110_pop165_mut.01_snapshot_500.csv
            'https://osf.io/8ycq7/',
            # nk_randomselection_seed7_pop100_mut.01_snapshot_5000.csv
            'https://osf.io/ydxt7/',
            # nk_sharingselection_seed10_pop100_mut.01_snapshot_5000.csv
            'https://osf.io/cz9fk/',
            # nk_tournamentselection_seed140_pop100_mut.01_snapshot_5000.csv
            'https://osf.io/5ubn8/',
]

endomill.instantiate_over(
    parameter_packs=[
        {
            'reconstructed_phylogeny_url': reconstructed_phylogeny_url,
            'original_phylogeny_url': original_phylogeny_url,
        }
        for reconstructed_phylogeny_url, original_phylogeny_url
        in zip(reconstructed_phylogeny_urls, original_phylogeny_urls)
    ],
)
# Out:
# detected executing.endomill.ipynb file
# skipping instantiate_over

# %%
#define papermil parameters
reconstructed_phylogeny_url: str
original_phylogeny_url: str

# reconstructed_phylogeny_url = reconstructed_phylogeny_urls[0]
# original_phylogeny_url = original_phylogeny_urls[0]

# %%
import alifedata_phyloinformatics_convert as apc
from Bio import Phylo
import dendropy
from iterpop import iterpop as ip
from keyname import keyname as kn
from os.path import basename
import pandas as pd
import sys

# %%
sys.setrecursionlimit(100000) # data exceeds default recursion limit

# %%
nbm.print_metadata()
# Out:
# context: ci
# hostname: 943f9139d4bc
# interpreter: 3.8.12 (default, Jan 15 2022, 18:39:47)  [GCC 7.5.0]
# nbcellexec: 8
# nbname: reconstructed_phylogeny_evaluation_mill
# nbpath: /opt/hereditary-stratigraph-concept/binder/phylogenetic-inference/reconstructed_phylogeny_evaluation_mill.ipynb
# revision: null
# session: 0963e396-1d15-4b79-b9da-91ca0000fbab
# timestamp: 2022-03-09T04:15:29Z00:00
#
#
# IPython==7.16.1
# endomill==0.1.3
# ipykernel==5.5.3
# ipython_genutils==0.2.0
# json==2.0.9
# keyname==0.4.1
# logging==0.5.1.2
# nbmetalog==0.2.6
# re==2.2.1
# yaml==5.3.1
# zmq==22.3.0
# Bio==1.79
# alifedata_phyloinformatics_convert==0.6.0
# dendropy==4.5.2
# iterpop==0.4.0
# pandas==1.1.2

# %%
original_df = pd.read_csv(
    f'{original_phylogeny_url}/download',
)

original_df['name'] = original_df['id'].astype(str)
original_df['taxon_label'] = original_df['id'].astype(str)

nbm.print_dataframe_synopsis(original_df)
# Out:
# digest: 74499f208d51b3d9e36246a69e84eeffb1a4526b42032ae42c0bb98a70ba98ae
# manifest:
#   ancestor_list: '    3626#  ex., [316479]'
#   depth: '            3153#  ex., 3141'
#   destruction_time: ' 2743#  ex., inf'
#   id: '               3697#  ex., 316633'
#   name: '             3697#  ex., 316633'
#   num_offspring: '    5#     ex., 0'
#   num_orgs: '         5#     ex., 1'
#   origin_time: '      3211#  ex., 5000'
#   phenotype: '        3686#  ex., [ 0.797946 0.536379 0.443815 0.0526468 0.92057 0.91075
#     0.30778 0.492666 0.443872 0.822448 0.850668 0.622605 0.862708 0.278087 0.28528
#     0.595257 0.709313 0.589555 0.0954585 0.862811 0.681532 0.396538 0.940159 0.466114
#     0.964965 0.496943 0.931246 0.459464 0.323874 0.381974 0.457127 0.807726 0.439315
#     0.824859 0.57682 0.840605 0.720875 0.501633 0.541537 0.474429 0.260919 0.477315
#     0.382976 0.773835 0.691462 0.0166064 0.756788 0.431525 0.341946 0.359509 0.0311168
#     0.624921 0.449223 0.775889 0.485843 0.932592 0.949503 0.0422867 0.0536213 0.108818
#     0.958998 0.540366 0.456285 0.1875 0.899311 0.59706 0.425936 0.528831 0.537044
#     0.720292 0.957068 0.746681 0.392795 0.543939 0.166369 0.805668 0.255746 0.00774763
#     0.615083 0.0986629 0.281872 0.9853 0.26639 0.177044 0.341598 0.186309 0.403581
#     0.711326 0.62494 0.853904 0.441514 0.0418954 0.963581 0.172946 0.412749 0.86182
#     0.168004 0.631794 0.803979 0.449775 0.561051 0.221267 0.614246 0.477457 0.338633
#     0.083854 0.0683286 0.93391 0.172241 0.89929 0.103581 0.469125 0.18933 0.785515
#     0.816378 0.244662 0.191059 0.683141 0.283228 0.171559 0.621972 0.842445 0.774176
#     0.0384827 0.103506 0.916684 0.99534 0.861877 0.593288 0.766542 0.603295 0.830595
#     0.689014 0.915103 0.917971 0.415021 0.214791 0.72228 0.175467 0.361024 0.315883
#     0.232436 0.197379 0.514892 0.44128 0.784395 0.13556 0.792916 0.0526158 0.893615
#     0.437114 0.322495 0.923163 0.675438 0.290099 0.781006 0.791039 0.646287 0.318363
#     0.499775 0.322352 0.981775 0.26354 0.501267 0.466449 0.272334 0.239124 0.99981
#     0.476893 0.107192 0.128452 0.590622 0.279974 0.586513 0.218291 0.122193 0.554612
#     0.55965 0.947409 0.623455 0.0273677 0.422406 0.932761 0.763582 0.478453 0.761483
#     0.153003 0.254724 0.433007 0.395966 0.726484 0.450321 0.0919374 0.700726 0.375625
#     0.614861 0.759063 0.503891 0.729632 0.983236 ]'
#   taxon_label: '      3697#  ex., 316633'
#   tot_orgs: '         20#    ex., 1'
#   total_offspring: '  21#    ex., 0'
# num cols: 12
# num cols all na: 0
# num cols any na: 0
# num na: 0
# num rows: 3697
# num rows all na: 0
# num rows any na: 0
# size: 7M

# %%
reconstructed_df = pd.read_csv(
    f'{reconstructed_phylogeny_url}?raw=true',
    compression='gzip',
)
reconstructed_df['taxon_label'] = reconstructed_df['name']
reconstructed_df['Instance'] = reconstructed_df.apply(
    lambda row: row['Treatment'] + row['Algorithm'],
    axis=1,
)

nbm.print_dataframe_synopsis(reconstructed_df)

data_filename = basename(reconstructed_phylogeny_url)

print(data_filename)
# Out:
# digest: c7dbe99800857f55e15c01d11de6c771a485eab0e1c1578dbe2b0928e8faa33e
# manifest:
#   Algorithm: '     2#     ex., nj'
#   Instance: '      36#    ex., differentia=1+policy=RecencyProportionalResolution+target=1024nj'
#   Treatment: '     18#    ex., differentia=1+policy=RecencyProportionalResolution+target=1024'
#   'Unnamed: 0': '    5130#  ex., 0'
#   ancestor_list: ' 142#   ex., [None]'
#   branch_length: ' 1472#  ex., 0.0'
#   id: '            143#   ex., 0'
#   index: '         143#   ex., 0'
#   name: '          143#   ex., Inner70'
#   origin_time: '   2244#  ex., 0.0'
#   taxon_label: '   143#   ex., Inner70'
# num cols: 11
# num cols all na: 0
# num cols any na: 0
# num na: 0
# num rows: 5130
# num rows all na: 0
# num rows any na: 0
# size: 2M
#
# a=reconstructed_phylogenies+source=nk_randomselection_seed7_pop100_mut.01_snapshot_5000.csv.gz

# %%
endomill.add_instance_outpath(
    f'a=reconstructed_phylogeny_evaluation+source={kn.unpack(data_filename)["source"]}.endomill.ipynb',
)

# %%
#TODO: teeplot
actual_tree = apc.alife_dataframe_to_biopython_tree(original_df)
for inner_node in actual_tree.get_nonterminals():
    inner_node.name = None
Phylo.draw(actual_tree)
for instance, group in reconstructed_df.groupby('Instance'):
    tree = apc.alife_dataframe_to_biopython_tree(group)
    tree.root_at_midpoint()
    Phylo.draw(
        tree,
        label_func=lambda node: None if 'Inner' in str(node) else str(node),
    )

# %%
actual_tree = apc.alife_dataframe_to_dendropy_tree(original_df)
for inner_node in actual_tree.internal_nodes():
    inner_node.taxon = None

records = []
for instance, group in reconstructed_df.groupby('Instance'):
    tree = apc.alife_dataframe_to_dendropy_tree(group)
    tree.migrate_taxon_namespace(actual_tree.taxon_namespace)
    unweighted_robinson_foulds = dendropy.calculate.treecompare.unweighted_robinson_foulds_distance(
        actual_tree,
        tree,
    )
#     weighted_robinson_foulds = dendropy.calculate.treecompare.weighted_robinson_foulds_distance(
#         actual_tree,
#         tree,
#     )
#     euclidean = dendropy.calculate.treecompare.euclidean_distance(
#         actual_tree,
#         tree,
#     )

    records.append({
        **{
            'Instance': 'Instance',
            'Algorithm': ip.popsingleton(group['Algorithm'].unique()),
            'Treatment': ip.popsingleton(group['Treatment'].unique()),
            'Unweighted Robinson Foulds Distance Error': unweighted_robinson_foulds,
#             'Weighted Robinson Foulds Distance Error': weighted_robinson_foulds,
#             'Euclidean Distance Error': euclidean,
        },
        **kn.unpack(ip.popsingleton(group['Treatment'].unique())),
    })


res_df = pd.DataFrame.from_records(records)

# %%
res_df
# Out:
#     Instance Algorithm                                          Treatment  \
# 0   Instance        nj  differentia=1+policy=RecencyProportionalResolu...
# 1   Instance     upgma  differentia=1+policy=RecencyProportionalResolu...
# 2   Instance        nj  differentia=1+policy=RecencyProportionalResolu...
# 3   Instance     upgma  differentia=1+policy=RecencyProportionalResolu...
# 4   Instance        nj  differentia=1+policy=RecencyProportionalResolu...
# 5   Instance     upgma  differentia=1+policy=RecencyProportionalResolu...
# 6   Instance        nj  differentia=1+policy=TaperedDepthProportionalR...
# 7   Instance     upgma  differentia=1+policy=TaperedDepthProportionalR...
# 8   Instance        nj  differentia=1+policy=TaperedDepthProportionalR...
# 9   Instance     upgma  differentia=1+policy=TaperedDepthProportionalR...
# 10  Instance        nj  differentia=1+policy=TaperedDepthProportionalR...
# 11  Instance     upgma  differentia=1+policy=TaperedDepthProportionalR...
# 12  Instance        nj  differentia=64+policy=RecencyProportionalResol...
# 13  Instance     upgma  differentia=64+policy=RecencyProportionalResol...
# 14  Instance        nj  differentia=64+policy=RecencyProportionalResol...
# 15  Instance     upgma  differentia=64+policy=RecencyProportionalResol...
# 16  Instance        nj  differentia=64+policy=RecencyProportionalResol...
# 17  Instance     upgma  differentia=64+policy=RecencyProportionalResol...
# 18  Instance        nj  differentia=64+policy=TaperedDepthProportional...
# 19  Instance     upgma  differentia=64+policy=TaperedDepthProportional...
# 20  Instance        nj  differentia=64+policy=TaperedDepthProportional...
# 21  Instance     upgma  differentia=64+policy=TaperedDepthProportional...
# 22  Instance        nj  differentia=64+policy=TaperedDepthProportional...
# 23  Instance     upgma  differentia=64+policy=TaperedDepthProportional...
# 24  Instance        nj  differentia=8+policy=RecencyProportionalResolu...
# 25  Instance     upgma  differentia=8+policy=RecencyProportionalResolu...
# 26  Instance        nj  differentia=8+policy=RecencyProportionalResolu...
# 27  Instance     upgma  differentia=8+policy=RecencyProportionalResolu...
# 28  Instance        nj  differentia=8+policy=RecencyProportionalResolu...
# 29  Instance     upgma  differentia=8+policy=RecencyProportionalResolu...
# 30  Instance        nj  differentia=8+policy=TaperedDepthProportionalR...
# 31  Instance     upgma  differentia=8+policy=TaperedDepthProportionalR...
# 32  Instance        nj  differentia=8+policy=TaperedDepthProportionalR...
# 33  Instance     upgma  differentia=8+policy=TaperedDepthProportionalR...
# 34  Instance        nj  differentia=8+policy=TaperedDepthProportionalR...
# 35  Instance     upgma  differentia=8+policy=TaperedDepthProportionalR...
#
#     Unweighted Robinson Foulds Distance Error differentia  \
# 0                                          26           1
# 1                                          26           1
# 2                                          22           1
# 3                                          22           1
# 4                                          34           1
# 5                                          34           1
# 6                                          56           1
# 7                                          60           1
# 8                                          84           1
# 9                                          80           1
# 10                                        116           1
# 11                                        120           1
# 12                                         24          64
# 13                                         16          64
# 14                                         68          64
# 15                                         84          64
# 16                                         68          64
# 17                                         84          64
# 18                                        124          64
# 19                                        124          64
# 20                                        126          64
# 21                                        120          64
# 22                                        126          64
# 23                                        126          64
# 24                                         12           8
# 25                                         12           8
# 26                                         12           8
# 27                                         12           8
# 28                                         68           8
# 29                                         84           8
# 30                                         60           8
# 31                                         72           8
# 32                                         64           8
# 33                                         78           8
# 34                                        126           8
# 35                                        126           8
#
#                                 policy target  \
# 0        RecencyProportionalResolution   1024
# 1        RecencyProportionalResolution   1024
# 2        RecencyProportionalResolution    512
# 3        RecencyProportionalResolution    512
# 4        RecencyProportionalResolution     64
# 5        RecencyProportionalResolution     64
# 6   TaperedDepthProportionalResolution   1024
# 7   TaperedDepthProportionalResolution   1024
# 8   TaperedDepthProportionalResolution    512
# 9   TaperedDepthProportionalResolution    512
# 10  TaperedDepthProportionalResolution     64
# 11  TaperedDepthProportionalResolution     64
# 12       RecencyProportionalResolution   1024
# 13       RecencyProportionalResolution   1024
# 14       RecencyProportionalResolution    512
# 15       RecencyProportionalResolution    512
# 16       RecencyProportionalResolution     64
# 17       RecencyProportionalResolution     64
# 18  TaperedDepthProportionalResolution   1024
# 19  TaperedDepthProportionalResolution   1024
# 20  TaperedDepthProportionalResolution    512
# 21  TaperedDepthProportionalResolution    512
# 22  TaperedDepthProportionalResolution     64
# 23  TaperedDepthProportionalResolution     64
# 24       RecencyProportionalResolution   1024
# 25       RecencyProportionalResolution   1024
# 26       RecencyProportionalResolution    512
# 27       RecencyProportionalResolution    512
# 28       RecencyProportionalResolution     64
# 29       RecencyProportionalResolution     64
# 30  TaperedDepthProportionalResolution   1024
# 31  TaperedDepthProportionalResolution   1024
# 32  TaperedDepthProportionalResolution    512
# 33  TaperedDepthProportionalResolution    512
# 34  TaperedDepthProportionalResolution     64
# 35  TaperedDepthProportionalResolution     64
#
#                                                     _
# 0   differentia=1+policy=RecencyProportionalResolu...
# 1   differentia=1+policy=RecencyProportionalResolu...
# 2   differentia=1+policy=RecencyProportionalResolu...
# 3   differentia=1+policy=RecencyProportionalResolu...
# 4   differentia=1+policy=RecencyProportionalResolu...
# 5   differentia=1+policy=RecencyProportionalResolu...
# 6   differentia=1+policy=TaperedDepthProportionalR...
# 7   differentia=1+policy=TaperedDepthProportionalR...
# 8   differentia=1+policy=TaperedDepthProportionalR...
# 9   differentia=1+policy=TaperedDepthProportionalR...
# 10  differentia=1+policy=TaperedDepthProportionalR...
# 11  differentia=1+policy=TaperedDepthProportionalR...
# 12  differentia=64+policy=RecencyProportionalResol...
# 13  differentia=64+policy=RecencyProportionalResol...
# 14  differentia=64+policy=RecencyProportionalResol...
# 15  differentia=64+policy=RecencyProportionalResol...
# 16  differentia=64+policy=RecencyProportionalResol...
# 17  differentia=64+policy=RecencyProportionalResol...
# 18  differentia=64+policy=TaperedDepthProportional...
# 19  differentia=64+policy=TaperedDepthProportional...
# 20  differentia=64+policy=TaperedDepthProportional...
# 21  differentia=64+policy=TaperedDepthProportional...
# 22  differentia=64+policy=TaperedDepthProportional...
# 23  differentia=64+policy=TaperedDepthProportional...
# 24  differentia=8+policy=RecencyProportionalResolu...
# 25  differentia=8+policy=RecencyProportionalResolu...
# 26  differentia=8+policy=RecencyProportionalResolu...
# 27  differentia=8+policy=RecencyProportionalResolu...
# 28  differentia=8+policy=RecencyProportionalResolu...
# 29  differentia=8+policy=RecencyProportionalResolu...
# 30  differentia=8+policy=TaperedDepthProportionalR...
# 31  differentia=8+policy=TaperedDepthProportionalR...
# 32  differentia=8+policy=TaperedDepthProportionalR...
# 33  differentia=8+policy=TaperedDepthProportionalR...
# 34  differentia=8+policy=TaperedDepthProportionalR...
# 35  differentia=8+policy=TaperedDepthProportionalR...

# %%
nbm.print_dataframe_synopsis(res_df)
# Out:
# digest: 0043e24484148b821cb43297f4f7d6121844375492b1d56801e707cbf23a66b2
# manifest:
#   Algorithm: '                                 2#   ex., nj'
#   Instance: '                                  1#   ex., Instance'
#   Treatment: '                                 18#  ex., differentia=1+policy=RecencyProportionalResolution+target=1024'
#   Unweighted Robinson Foulds Distance Error: ' 18#  ex., 26'
#   _: '                                         18#  ex., differentia=1+policy=RecencyProportionalResolution+target=1024'
#   differentia: '                               3#   ex., 1'
#   policy: '                                    2#   ex., RecencyProportionalResolution'
#   target: '                                    3#   ex., 1024'
# num cols: 8
# num cols all na: 0
# num cols any na: 0
# num na: 0
# num rows: 36
# num rows all na: 0
# num rows any na: 0
# size: 20K

# %%
res_df.to_csv(
    f'a=reconstructed_phylogeny_evaluation+source={kn.unpack(data_filename)["source"]}',
    compression='gzip',
)
